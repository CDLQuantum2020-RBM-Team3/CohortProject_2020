# %% [markdown]
# # Task #1
#
# A template code for training an RBM on H$_2$ data for $r = 1.2$ is shown here. Modify this!
#
# Imports and loading in data:

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

from RBM_helper import RBM

import H2_energy_calculator

r = np.array(range(20,290,5)) / 100.0 
coeff = np.loadtxt("H2_data/H2_coefficients.txt")[:,:]
training_data = []

for i in range(len(r)):
    training_data.append(torch.from_numpy(np.loadtxt("H2_data/R_"+str(r[i])+"_samples.txt")))

# %% [markdown]
# Define the RBM:

# %%
n_vis = 2
n_hin = 20

rbm = RBM(n_vis, n_hin)

# %% [markdown]
# Train the RBM:

# %%
epochs = 10 # number of training steps, normally 500
update_epoch = 5 #the epoch which the energy is recalcualted, normally 100
num_samples = 1000 # number of samples to generate from the RBM to calculate the H2 energy, normally 1000
energiesList = []
true_energiesList = []

for i in range(len(r)):
    
    true_energy = H2_energy_calculator.energy_from_freq(training_data[i], coeff[i])
    print("\n--------------------------RBM-" + str(i) + "---------------------------")
    print("\nTrue Energy: %s for r = %s." % (true_energy, r[i]))

    for e in range(1, epochs+1):
        # do one epoch of training
        rbm.train(training_data[i])   

        # now generate samples and calculate the energy
        if e % update_epoch == 0:
            print("\nEpoch: ", e)
            print("Sampling the RBM...")

            # For sampling the RBM, we need to do Gibbs sampling.
            # Initialize the Gibbs sampling chain with init_state as defined below.
            init_state = torch.zeros(num_samples, n_vis)
            RBM_samples = rbm.draw_samples(15, init_state)

            print("Done sampling. Calculating energy...")       

            energies = H2_energy_calculator.energy(RBM_samples, coeff[i], rbm.wavefunction) 
            print("Energy from RBM samples: ", energies.item())
    print("\nFinal RBM Energy: ", energies.item())
    energiesList.append(energies.item())
    true_energiesList.append(true_energy)
# Out:
# --------------------------RBM-0---------------------------
#
# True Energy: 0.1442108747311382 for r = 0.2.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  0.3310292383600186
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  0.25916153703101996
#
# Final RBM Energy:  0.25916153703101996
#
# --------------------------RBM-1---------------------------
#
# True Energy: -0.3239354753254609 for r = 0.25.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.28362351357204796
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.2738321510898521
#
# Final RBM Energy:  -0.2738321510898521
#
# --------------------------RBM-2---------------------------
#
# True Energy: -0.6129039934108024 for r = 0.3.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.5744800022883331
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.5671660468929947
#
# Final RBM Energy:  -0.5671660468929947
#
# --------------------------RBM-3---------------------------
#
# True Energy: -0.8005095231150423 for r = 0.35.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.7604099896208456
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.7611694142528707
#
# Final RBM Energy:  -0.7611694142528707
#
# --------------------------RBM-4---------------------------
#
# True Energy: -0.9252580817605963 for r = 0.4.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.8899206365629505
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.902843699151516
#
# Final RBM Energy:  -0.902843699151516
#
# --------------------------RBM-5---------------------------
#
# True Energy: -1.0090086249753596 for r = 0.45.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.983333824697892
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9782636965086605
#
# Final RBM Energy:  -0.9782636965086605
#
# --------------------------RBM-6---------------------------
#
# True Energy: -1.0653912902153568 for r = 0.5.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0393964536067006
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0400416788021902
#
# Final RBM Energy:  -1.0400416788021902
#
# --------------------------RBM-7---------------------------
#
# True Energy: -1.1022968998091114 for r = 0.55.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0783811198062547
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.053370253819809
#
# Final RBM Energy:  -1.053370253819809
#
# --------------------------RBM-8---------------------------
#
# True Energy: -1.1255870371941183 for r = 0.6.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0885421261184787
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0966699273128577
#
# Final RBM Energy:  -1.0966699273128577
#
# --------------------------RBM-9---------------------------
#
# True Energy: -1.1389408436501118 for r = 0.65.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.097005804418672
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0981644136335171
#
# Final RBM Energy:  -1.0981644136335171
#
# --------------------------RBM-10---------------------------
#
# True Energy: -1.1449518561275118 for r = 0.7.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.1050744275104278
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0989467295348883
#
# Final RBM Energy:  -1.0989467295348883
#
# --------------------------RBM-11---------------------------
#
# True Energy: -1.1455985374846125 for r = 0.75.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.1035965884706382
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0858977051704424
#
# Final RBM Energy:  -1.0858977051704424
#
# --------------------------RBM-12---------------------------
#
# True Energy: -1.1426275996357373 for r = 0.8.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0735620932269223
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0853613179680213
#
# Final RBM Energy:  -1.0853613179680213
#
# --------------------------RBM-13---------------------------
#
# True Energy: -1.1366197707399515 for r = 0.85.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0895461297927245
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0638843259144526
#
# Final RBM Energy:  -1.0638843259144526
#
# --------------------------RBM-14---------------------------
#
# True Energy: -1.1285246121015233 for r = 0.9.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0730498725947366
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0683044793426695
#
# Final RBM Energy:  -1.0683044793426695
#
# --------------------------RBM-15---------------------------
#
# True Energy: -1.11929731061878 for r = 0.95.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.044595648649918
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0596664304894265
#
# Final RBM Energy:  -1.0596664304894265
#
# --------------------------RBM-16---------------------------
#
# True Energy: -1.1088894817596542 for r = 1.0.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0257845602725122
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0386670225185926
#
# Final RBM Energy:  -1.0386670225185926
#
# --------------------------RBM-17---------------------------
#
# True Energy: -1.0980083757150465 for r = 1.05.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0237431658588791
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0193184021195754
#
# Final RBM Energy:  -1.0193184021195754
#
# --------------------------RBM-18---------------------------
#
# True Energy: -1.0868155659324854 for r = 1.1.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9806238549818245
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -1.0209315041937677
#
# Final RBM Energy:  -1.0209315041937677
#
# --------------------------RBM-19---------------------------
#
# True Energy: -1.0753656599951444 for r = 1.15.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9839893684760159
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9874583659595104
#
# Final RBM Energy:  -0.9874583659595104
#
# --------------------------RBM-20---------------------------
#
# True Energy: -1.0642022250418146 for r = 1.2.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9814667665081387
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.992326749707196
#
# Final RBM Energy:  -0.992326749707196
#
# --------------------------RBM-21---------------------------
#
# True Energy: -1.0534371372280913 for r = 1.25.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.981735566280834
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9821388800198756
#
# Final RBM Energy:  -0.9821388800198756
# --------------------------RBM-22---------------------------
#
# True Energy: -1.0429909176307628 for r = 1.3.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9741985499362045
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9917340254775584
#
# Final RBM Energy:  -0.9917340254775584
#
# --------------------------RBM-23---------------------------
#
# True Energy: -1.0329255626795484 for r = 1.35.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9741731898245597
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.980347184711033
#
# Final RBM Energy:  -0.980347184711033
#
# --------------------------RBM-24---------------------------
#
# True Energy: -1.0235793844779455 for r = 1.4.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9795748810047887
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.961042747123409
#
# Final RBM Energy:  -0.961042747123409
#
# --------------------------RBM-25---------------------------
#
# True Energy: -1.0148219637906388 for r = 1.45.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.962298862302388
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.982004160179186
#
# Final RBM Energy:  -0.982004160179186
#
# --------------------------RBM-26---------------------------
#
# True Energy: -1.0066304034616804 for r = 1.5.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9684219443718944
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9484036640022082
#
# Final RBM Energy:  -0.9484036640022082
#
# --------------------------RBM-27---------------------------
#
# True Energy: -0.999024596529867 for r = 1.55.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9588644502723025
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9795397729243565
#
# Final RBM Energy:  -0.9795397729243565
#
# --------------------------RBM-28---------------------------
#
# True Energy: -0.9922208295295207 for r = 1.6.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9639222674570834
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9601547828660433
#
# Final RBM Energy:  -0.9601547828660433
#
# --------------------------RBM-29---------------------------
#
# True Energy: -0.9858019801897505 for r = 1.65.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9561477120210138
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9687320561250278
#
# Final RBM Energy:  -0.9687320561250278
#
# --------------------------RBM-30---------------------------
#
# True Energy: -0.9800155269872984 for r = 1.7.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9578137496450392
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9587681878673342
#
# Final RBM Energy:  -0.9587681878673342
#
# --------------------------RBM-31---------------------------
#
# True Energy: -0.9751547052866764 for r = 1.75.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9449776272888641
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9521511856594487
#
# Final RBM Energy:  -0.9521511856594487
#
# --------------------------RBM-32---------------------------
#
# True Energy: -0.9708063813726302 for r = 1.8.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9553051042850627
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9477750134308193
#
# Final RBM Energy:  -0.9477750134308193
#
# --------------------------RBM-33---------------------------
#
# True Energy: -0.9668194250398201 for r = 1.85.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9453326198788928
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9474680285305543
#
# Final RBM Energy:  -0.9474680285305543
#
# --------------------------RBM-34---------------------------
#
# True Energy: -0.9632910274850663 for r = 1.9.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9444845094345797
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9506162523551682
#
# Final RBM Energy:  -0.9506162523551682
#
# --------------------------RBM-35---------------------------
#
# True Energy: -0.9603380642016857 for r = 1.95.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9312679429570002
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9486721888237875
#
# Final RBM Energy:  -0.9486721888237875
#
# --------------------------RBM-36---------------------------
#
# True Energy: -0.9576117229960116 for r = 2.0.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9427849920177643
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9415131585281558
#
# Final RBM Energy:  -0.9415131585281558
#
# --------------------------RBM-37---------------------------
#
# True Energy: -0.9552226828746918 for r = 2.05.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.942382716301352
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9442175507370066
#
# Final RBM Energy:  -0.9442175507370066
#
# --------------------------RBM-38---------------------------
#
# True Energy: -0.953433481076329 for r = 2.1.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.947346433050721
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9456735948938598
#
# Final RBM Energy:  -0.9456735948938598
#
# --------------------------RBM-39---------------------------
#
# True Energy: -0.9515983821584779 for r = 2.15.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9390989451615441
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9404074946370145
#
# Final RBM Energy:  -0.9404074946370145
#
# --------------------------RBM-40---------------------------
#
# True Energy: -0.9501822397766282 for r = 2.2.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9413088421497013
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9446609056348192
#
# Final RBM Energy:  -0.9446609056348192
#
# --------------------------RBM-41---------------------------
#
# True Energy: -0.9490056352051295 for r = 2.25.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9345453860010391
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9356958631579575
#
# Final RBM Energy:  -0.9356958631579575
#
# --------------------------RBM-42---------------------------
#
# True Energy: -0.9478686468761977 for r = 2.3.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9387197547799663
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.940553692187421
#
# Final RBM Energy:  -0.940553692187421
#
# --------------------------RBM-43---------------------------
#
# True Energy: -0.9469689234886285 for r = 2.35.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9336820566178545
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9469343377629091
#
# Final RBM Energy:  -0.9469343377629091
# --------------------------RBM-44---------------------------
#
# True Energy: -0.9461560561584954 for r = 2.4.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9444370479051795
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9354632472195827
#
# Final RBM Energy:  -0.9354632472195827
#
# --------------------------RBM-45---------------------------
#
# True Energy: -0.9454307947133701 for r = 2.45.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9394401585818217
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9396869294656891
#
# Final RBM Energy:  -0.9396869294656891
#
# --------------------------RBM-46---------------------------
#
# True Energy: -0.9448669090603318 for r = 2.5.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9351257839216205
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9412983158884234
#
# Final RBM Energy:  -0.9412983158884234
#
# --------------------------RBM-47---------------------------
#
# True Energy: -0.944544970980179 for r = 2.55.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9416186838626295
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9393061541834263
#
# Final RBM Energy:  -0.9393061541834263
#
# --------------------------RBM-48---------------------------
#
# True Energy: -0.9441460761802778 for r = 2.6.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9387625241249741
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9422013098009853
#
# Final RBM Energy:  -0.9422013098009853
#
# --------------------------RBM-49---------------------------
#
# True Energy: -0.9438417682698376 for r = 2.65.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9382233050106583
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9353873128931297
#
# Final RBM Energy:  -0.9353873128931297
#
# --------------------------RBM-50---------------------------
#
# True Energy: -0.9436642235552212 for r = 2.7.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9395429789274474
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9304716881020793
#
# Final RBM Energy:  -0.9304716881020793
#
# --------------------------RBM-51---------------------------
#
# True Energy: -0.9432234998867722 for r = 2.75.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9346970216170298
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9382864828863868
#
# Final RBM Energy:  -0.9382864828863868
#
# --------------------------RBM-52---------------------------
#
# True Energy: -0.9431717178456402 for r = 2.8.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9418412842389645
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9388027375810273
#
# Final RBM Energy:  -0.9388027375810273
#
# --------------------------RBM-53---------------------------
#
# True Energy: -0.9429293235489895 for r = 2.85.
#
# Epoch:  5
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9418216055776214
#
# Epoch:  10
# Sampling the RBM...
# Done sampling. Calculating energy...
# Energy from RBM samples:  -0.9348955999705422
#
# Final RBM Energy:  -0.9348955999705422

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.plot(r,energiesList)

#Define plots
rbm_plot = ax.plot(r, energiesList, label='RBM')
true_plot = ax.plot(r, true_energiesList, dashes=[6, 2], label='True Energy')

#Text formating
params = {'mathtext.default': 'regular' }  
plt.rcParams.update(params)
plt.xlabel('$r$', fontsize=14)
y = plt.ylabel('$E_{bond}$', fontsize=14)
plt.title('H2 Potential Energy Curve using RBMs', fontsize=16)
plt.text(r[-25], energiesList[0] - 0.05, "n = " + str(epochs))
plt.text(r[-25], energiesList[0] - 0.25, "s = " + str(num_samples))
plt.text(r[-25], energiesList[0] - 0.45, "n_vis = " + str(n_vis))
plt.text(r[-25], energiesList[0] - 0.65, "n_hid = " + str(n_hin))

ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
